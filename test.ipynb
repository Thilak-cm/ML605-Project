# %%
import pandas as pd

# Load the data from the specified parquet file
data_path = 'data/yellow_tripdata_2025-01.parquet'
data = pd.read_parquet(data_path)

# Display the first few rows of the dataframe to verify the data
data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 5
#       3 # Load the data from the specified parquet file
#       4 data_path = 'data/yellow_tripdata_2025-01.parquet'
# ----> 5 data = pd.read_parquet(data_path)
#       7 # Display the first few rows of the dataframe to verify the data
#       8 data.head()
#
# File ~/anaconda3/envs/ML-AI/lib/python3.11/site-packages/pandas/io/parquet.py:670, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     667     use_nullable_dtypes = False
#     668 check_dtype_backend(dtype_backend)
# --> 670 return impl.read(
#     671     path,
#     672     columns=columns,
#     673     filters=filters,
#     674     storage_options=storage_options,
#     675     use_nullable_dtypes=use_nullable_dtypes,
#     676     dtype_backend=dtype_backend,
# ...

# %%
data.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'Airport_fee'],
#       dtype='object')

# %%
data['PULocationID'].nunique()
# Out:
# 261

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3475226 entries, 0 to 3475225
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int32
#  1   tpep_pickup_datetime   datetime64[us]
#  2   tpep_dropoff_datetime  datetime64[us]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int32
#  8   DOLocationID           int32
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  Airport_fee            float64
# dtypes: datetime64[us](2), float64(12), int32(3), int64(1), object(1)
# ...

# %%
import pandas as pd
pd.read_csv('data_from_2024/merged_features.csv').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10007 entries, 0 to 10006
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   hour                           10007 non-null  object
#  1   trip_count                     10007 non-null  int64
#  2   unique_vendors                 10007 non-null  int64
#  3   avg_distance                   10007 non-null  float64
#  4   total_distance                 10007 non-null  float64
#  5   unique_pickup_locs             10007 non-null  int64
#  6   is_holiday                     10007 non-null  bool
#  7   demand                         10007 non-null  float64
#  8   dt_iso                         10007 non-null  object
#  9   temp                           10007 non-null  float64
#  10  feels_like                     10007 non-null  float64
#  11  temp_min                       10007 non-null  float64
# ...

# %%
import pandas as pd

df = pd.read_csv('data_from_2024/taxi_demand_dataset.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 274107 entries, 0 to 274106
# Data columns (total 71 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   hour                           274107 non-null  object
#  1   zone_id                        274107 non-null  int64
#  2   unique_vendors                 274107 non-null  int64
#  3   avg_distance                   274107 non-null  float64
#  4   total_distance                 274107 non-null  float64
#  5   is_holiday                     274107 non-null  int64
#  6   demand                         274107 non-null  int64
#  7   demand_log                     274107 non-null  float64
#  8   demand_rolling_mean            274107 non-null  float64
#  9   demand_rolling_std             274107 non-null  float64
#  10  demand_zscore                  274107 non-null  float64
#  11  demand_rolling_min             274107 non-null  float64
# ...

# %%
df[['temp', 'feels_like', 'wind_speed', 'rain_1h']]
# Out:
#         temp  feels_like  wind_speed  rain_1h
# 0       5.49        2.21        4.47     0.12
# 1       5.42        2.31        4.12     0.14
# 2       4.15        1.74        2.68     0.27
# 3       4.48        2.20        2.60     0.28
# 4       5.21        2.69        3.10     0.51
# ...      ...         ...         ...      ...
# 274102  4.33        0.33        5.36     0.00
# 274103  5.02        0.82        6.26     0.00
# 274104  5.81        3.10        3.58     0.00
# 274105  6.54        4.27        3.13     0.00
# 274106  7.83        5.55        3.60     0.00
#
# [274107 rows x 4 columns]

# %%
import pandas as pd
df = pd.read_csv("https://huggingface.co/datasets/thillsss/Taxi-Demand-Prediction-Dataset/resolve/main/taxi_demand_dataset.csv")

# %%
df.head()
# Out:
#                   hour  zone_id  unique_vendors  avg_distance  total_distance  \
# 0  2024-01-01 05:00:00        1               1      0.000000            0.00
# 1  2024-01-01 06:00:00        1               1      0.015000            0.06
# 2  2024-01-01 13:00:00        1               2      0.000000            0.00
# 3  2024-01-01 14:00:00        1               2      0.001667            0.01
# 4  2024-01-01 15:00:00        1               2      0.000000            0.00
#
#    is_holiday  demand  demand_log  demand_rolling_mean  demand_rolling_std  \
# 0           1       1    0.693147             1.000000            2.121320
# 1           1       4    1.609438             2.500000            2.121320
# 2           1       3    1.386294             2.666667            1.527525
# 3           1       6    1.945910             3.500000            2.081666
# 4           1       2    1.098612             3.200000            1.923538
#
# ...

# %%
import pandas as pd
df = pd.read_csv('data_from_2024/taxi_demand_dataset.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 274107 entries, 0 to 274106
# Data columns (total 71 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   hour                           274107 non-null  object
#  1   zone_id                        274107 non-null  int64
#  2   unique_vendors                 274107 non-null  int64
#  3   avg_distance                   274107 non-null  float64
#  4   total_distance                 274107 non-null  float64
#  5   is_holiday                     274107 non-null  int64
#  6   demand                         274107 non-null  int64
#  7   demand_log                     274107 non-null  float64
#  8   demand_rolling_mean            274107 non-null  float64
#  9   demand_rolling_std             274107 non-null  float64
#  10  demand_zscore                  274107 non-null  float64
#  11  demand_rolling_min             274107 non-null  float64
# ...
